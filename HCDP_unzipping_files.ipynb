# %% [markdown]
# <a href="https://colab.research.google.com/github/hayleypc/HawaiiClimate/blob/main/HCDP_unzipping_files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os
import zipfile

# %%
# Step 1: Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# # Step 2: Set the path of the zipped file in Google Drive
# zip_path = "/content/drive/MyDrive/03_HI_soil_analysis/hawaii_soils/HCDP_Hawaii_Climate_Data_Portal/HCDP_data.zip"

# %%
# # Step 3: Define extraction directory
# extract_dir = "/content/drive/MyDrive/03_HI_soil_analysis/hawaii_soils/HCDP_Hawaii_Climate_Data_Portal/unzipped_folder"

# %%
# # Step 4: Unzip the file
# with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#     zip_ref.extractall(extract_dir)

# # Step 5: List the contents of the extracted folder
# for root, dirs, files in os.walk(extract_dir):
#     print(f"Directory: {root}")
#     for file in files:
#         print(f" - {file}")
# Out:
# Streaming output truncated to the last 5000 lines.
#  - rainfall_new_month_statewide_anom_se_1992_05.tif
#  - rainfall_new_month_statewide_anom_se_1992_06.tif
#  - rainfall_new_month_statewide_anom_se_1992_07.tif
#  - rainfall_new_month_statewide_anom_se_1992_08.tif
#  - rainfall_new_month_statewide_anom_se_1992_09.tif
#  - rainfall_new_month_statewide_anom_se_1992_10.tif
#  - rainfall_new_month_statewide_anom_se_1992_11.tif
#  - rainfall_new_month_statewide_anom_se_1992_12.tif
# Directory: /content/drive/MyDrive/03_HI_soil_analysis/hawaii_soils/HCDP_Hawaii_Climate_Data_Portal/unzipped_folder/rainfall/new/month/statewide/anom_se/1993
#  - rainfall_new_month_statewide_anom_se_1993_01.tif
#  - rainfall_new_month_statewide_anom_se_1993_02.tif
#  - rainfall_new_month_statewide_anom_se_1993_03.tif
#  - rainfall_new_month_statewide_anom_se_1993_04.tif
#  - rainfall_new_month_statewide_anom_se_1993_05.tif
#  - rainfall_new_month_statewide_anom_se_1993_06.tif
# ...
